# %%
# !pip install snscrape
# Run the below command if you don't already have Pandas
# !pip install pandas

# Imports
import snscrape.modules.twitter as sntwitter
import pandas as pd
from itertools import islice
from datetime import date
from dateutil.rrule import rrule, DAILY

# %%
# Below are two ways of scraping using the Python Wrapper.
# Comment or uncomment as you need. If you currently run the script as is it will scrape both queries
# then output two different csv files.

# Query by username
# Setting variables to be used below
# maxTweets = 5000

# Creating list to append tweet data to
# tweets_list1 = []

# # Using TwitterSearchScraper to scrape data 
# for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:NVIDIA').get_items()):
#     if i>=maxTweets:
#         break
#     tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
# print('WILLIAM\'S TEST:', len(tweets_list1))

# for tweet in tweets_list1:
#     print(tweet)
    
# # Creating a dataframe from the tweets list above
# tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# # Display first 5 entries from dataframe
# # tweets_df1.head()

# # Export dataframe into a CSV
# tweets_df1.to_csv('user-tweets.csv', sep=',', index=False)


# Query by text search
# Setting variables to be used below
maxTweets = 100

# Creating list to append tweet data to
tweets_list2 = []

start = date(2014, 9, 30)
end = date(2022, 11, 28)
start_end = date(2014, 10, 1)
end_end = date(2022, 11, 29)

for ds, de in zip(rrule(DAILY, dtstart=start, until=end), rrule(DAILY, dtstart=start_end, until=end_end)):
    start_day = ds.strftime("%Y-%m-%d")
    end_day = de.strftime("%Y-%m-%d") 
    print(start_day)
# Using TwitterSearchScraper to scrape data and append tweets to list
    for tweet in islice(sntwitter.TwitterSearchScraper(f'JensonH since:{start_day} until:{end_day} lang:en', max).get_items(), maxTweets):
        #if i>maxTweets:
            #break
        tweets_list2.append([tweet.date, tweet.content])

    # Creating a dataframe from the tweets list above
    tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Text'])


    # Export dataframe into a CSV
    tweets_df2.to_csv(f'JensonH_tweet_{start_day}.csv', sep=',', index=False)
    
    tweets_list2 = []
# Out:
# 2014-09-30
# 2014-10-01
# 2014-10-02
# 2014-10-03
# 2014-10-04
# 2014-10-05
# 2014-10-06
# 2014-10-07
# 2014-10-08
# 2014-10-09
# 2014-10-10
# 2014-10-11
# 2014-10-12
# 2014-10-13
# 2014-10-14
# 2014-10-15
# 2014-10-16
# 2014-10-17
# 2014-10-18
# 2014-10-19
# 2014-10-20
# 2014-10-21
# 2014-10-22
# 2014-10-23
# 2014-10-24
# 2014-10-25
# 2014-10-26
# 2014-10-27
# 2014-10-28
# 2014-10-29
# 2014-10-30
# 2014-10-31
# 2014-11-01
# 2014-11-02
# 2014-11-03
# 2014-11-04
# 2014-11-05
# 2014-11-06
# 2014-11-07
# 2014-11-08
# 2014-11-09
# 2014-11-10
# 2014-11-11
# 2014-11-12
# 2014-11-13
# 2014-11-14
# 2014-11-15
# 2014-11-16
# 2014-11-17
# 2014-11-18
# 2014-11-19
# 2014-11-20
# 2014-11-21
# 2014-11-22
# 2014-11-23
# 2014-11-24
# 2014-11-25
# 2014-11-26
# 2014-11-27
# 2014-11-28
# 2014-11-29
# 2014-11-30
# 2014-12-01
# 2014-12-02
# 2014-12-03
# 2014-12-04
# 2014-12-05
# 2014-12-06
# 2014-12-07
# 2014-12-08
# 2014-12-09
# 2014-12-10
# 2014-12-11
# 2014-12-12
# 2014-12-13
# 2014-12-14
# ...
